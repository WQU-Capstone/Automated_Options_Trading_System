# %%
# Importing libraries

# %matplotlib inline

import pandas_datareader as pdr
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statistics as stats
import math
from scipy.stats import norm
import statsmodels.api as sm
import requests
from io import BytesIO
import datetime as dt

#import alpaca_trade_api as tradeapi

# %%
# Set Data Date

start = dt.datetime(2000, 1, 1)
end = dt.datetime(2020, 1, 1)

# %%
# Download Data

spy_df = pdr.get_data_yahoo(symbols='SPY', start = start, end = end)
vix_df = pdr.get_data_yahoo(symbols='^VIX', start = start, end = end)

# %%
# spy_df = spy_df.resample('D').asfreq()
# vix_df = vix_df.resample('D').asfreq()

# %%
# Calculate Daily Returns

spy_df['Daily Return'] = (spy_df['Adj Close'] / spy_df['Adj Close'].shift(1)) -1
spy_df.dropna(inplace = True)

# %%
# Fit the markov model

mod_spy_df = sm.tsa.MarkovAutoregression(spy_df['Daily Return'], k_regimes = 2, order = 1, switching_ar = True)
res_spy_df = mod_spy_df.fit()
# Out:
# /anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:583: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)

# %%
# Get the results

res_spy_df.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                          Markov Switching Model Results
# ================================================================================
# Dep. Variable:             Daily Return   No. Observations:                 5029
# Model:             MarkovAutoregression   Log Likelihood               15305.323
# Date:                  Thu, 22 Oct 2020   AIC                         -30596.646
# Time:                          10:55:20   BIC                         -30550.986
# Sample:                               0   HQIC                        -30580.648
#                                  - 5029
# Covariance Type:                 approx
#                              Regime 0 parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0031      0.001     -3.080      0.002      -0.005      -0.001
# ar.L1          1.0000      0.078     12.874      0.000       0.848       1.152
#                              Regime 1 parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0009      0.000      5.079      0.000       0.001       0.001
# ar.L1         -0.1966      0.018    -10.928      0.000      -0.232      -0.161
#                            Non-switching parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2         0.0001   2.67e-06     44.791      0.000       0.000       0.000
#                          Regime transition parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# p[0->0]        0.0748      0.033      2.254      0.024       0.010       0.140
# p[1->0]        0.1257      0.025      5.019      0.000       0.077       0.175
# ==============================================================================
#
# Warnings:
# [1] Covariance matrix calculated using numerical (complex-step) differentiation.
# """

# %%
# Plot the probabilties

fig, axes = plt.subplots(2, figsize=(7,7))

ax = axes[0]
ax.plot(res_spy_df.filtered_marginal_probabilities[0])
ax.set_xlim(spy_df.index[4], spy_df.index[-1])
ax.set(title = 'Filtered probability of recession')

ax = axes[1]
ax.plot(res_spy_df.smoothed_marginal_probabilities[0])
ax.set_xlim(spy_df.index[4], spy_df.index[-1])
ax.set(title = 'Smoothed probability of recession')

fig.tight_layout()

# %%
# Get the expected duration

print(res_spy_df.expected_durations)
# Out:
# [1.08085332 7.953931  ]

# %%
# Adding Bollinger Bands as technical indicator for portfolio rebalancing

spy_df['20 day moving average'] = spy_df['Adj Close'].rolling(window=20).mean()

spy_df['20 day std'] = spy_df['Adj Close'].rolling(window=20).std()

spy_df['Upper Band'] = spy_df['20 day moving average'] + (spy_df['20 day std'] * 1.5)
spy_df['Lower Band'] = spy_df['20 day moving average'] - (spy_df['20 day std'] * 1.5)

# %%
# Setup Call & Put functions
def d_1(sigma, T, S, K, r):
    return 1/(sigma*np.sqrt(T))*(np.log(S/K)+(r+(sigma**2)/2)*T)

def d_2(d_1, sigma, T):
    return d_1 - sigma*np.sqrt(T)

def Call(sigma, T, S, K, r):
    d1 = d_1(sigma, T, S, K, r)
    d2 = d_2(d1, sigma, T)
    return norm.cdf(d1)*S-norm.cdf(d2)*K*np.exp(-r*T)

def Put(sigma, T, S, K, r):
    d1 = d_1(sigma, T, S, K, r)
    d2 = d_2(d1, sigma, T)
    return norm.cdf(-d2)*K*np.exp(-r*T)-norm.cdf(-d1)*S

# %%
# Out:
# State: 0.0
# option invested on 2000-02-18 00:00:00 premium: 2.7637636517636324 option type: c direction: l
# Option expires 2000-03-20 00:00:00 return: 7.621864318847656
# State: 0.0
# option invested on 2000-03-21 00:00:00 premium: 2.553359991391332 option type: p direction: l
# Option expires 2000-04-24 00:00:00 return: 4.713569641113281
# State: 0.0
# option invested on 2000-05-23 00:00:00 premium: 2.8117946885558354 option type: c direction: l
# Option expires 2000-06-23 00:00:00 return: 4.562347412109375
# State: 0.0
# option invested on 2000-06-29 00:00:00 premium: 2.247572667600231 option type: c direction: l
# Option expires 2000-07-31 00:00:00 return: 0
# State: 0.0
# option invested on 2000-08-17 00:00:00 premium: 2.0797552187859765 option type: p direction: l
# Option expires 2000-09-18 00:00:00 return: 3.51947021484375
# State: 0.0
# option invested on 2000-09-19 00:00:00 premium: 2.262703241308621 option type: c direction: l
# Option expires 2000-10-20 00:00:00 return: 0
# State: 0.0
# option invested on 2000-11-06 00:00:00 premium: 2.791379065109453 option type: p direction: l
# Option expires 2000-12-07 00:00:00 return: 6.912750244140625
# State: 0.0
# option invested on 2000-12-19 00:00:00 premium: 2.8033613085364237 option type: c direction: l
# Option expires 2001-01-19 00:00:00 return: 2.7393646240234375
# State: 0.0
# option invested on 2001-01-23 00:00:00 premium: 2.3317011391986853 option type: p direction: l
# Option expires 2001-02-23 00:00:00 return: 7.539207458496094
# State: 0.0
# option invested on 2001-03-13 00:00:00 premium: 2.623773366130145 option type: c direction: l
# Option expires 2001-04-16 00:00:00 return: 0
# State: 0.0
# option invested on 2001-04-17 00:00:00 premium: 2.4313865898969595 option type: p direction: l
# Option expires 2001-05-18 00:00:00 return: 0
# State: 0.0
# option invested on 2001-05-21 00:00:00 premium: 2.1794476474559588 option type: p direction: l
# Option expires 2001-06-21 00:00:00 return: 5.134910583496094
# State: 0.0
# option invested on 2001-07-09 00:00:00 premium: 2.150414703003392 option type: c direction: l
# Option expires 2001-08-09 00:00:00 return: 0
# State: 0.0
# option invested on 2001-08-17 00:00:00 premium: 2.2232415479447596 option type: c direction: l
# Option expires 2001-09-17 00:00:00 return: 0
# State: 0.0
# option invested on 2001-09-18 00:00:00 premium: 3.2200810119654264 option type: c direction: l
# Option expires 2001-10-19 00:00:00 return: 2.5498886108398438
# State: 0.0
# option invested on 2001-10-25 00:00:00 premium: 2.60764176340016 option type: p direction: l
# Option expires 2001-11-26 00:00:00 return: 0
# State: 0.0
# option invested on 2001-12-05 00:00:00 premium: 2.1674359465667976 option type: p direction: l
# Option expires 2002-01-07 00:00:00 return: 0.1439666748046875
# State: 0.0
# option invested on 2002-01-16 00:00:00 premium: 2.128764665824903 option type: c direction: l
# Option expires 2002-02-19 00:00:00 return: 0
# State: 0.0
# option invested on 2002-03-01 00:00:00 premium: 1.8292752824570897 option type: p direction: l
# Option expires 2002-04-01 00:00:00 return: 0
# State: 0.0
# option invested on 2002-04-03 00:00:00 premium: 1.8465757942423693 option type: c direction: l
# Option expires 2002-05-06 00:00:00 return: 0
# State: 0.0
# option invested on 2002-05-07 00:00:00 premium: 1.861745994645858 option type: c direction: l
# Option expires 2002-06-07 00:00:00 return: 0
# State: 0.0
# option invested on 2002-06-10 00:00:00 premium: 1.985463661491444 option type: c direction: l
# Option expires 2002-07-11 00:00:00 return: 0
# State: 0.0
# option invested on 2002-07-12 00:00:00 premium: 2.444092221592637 option type: c direction: l
# Option expires 2002-08-12 00:00:00 return: 0
# State: 0.0
# option invested on 2002-08-15 00:00:00 premium: 2.2245059955126933 option type: p direction: l
# Option expires 2002-09-16 00:00:00 return: 2.51983642578125
# State: 0.0
# option invested on 2002-09-18 00:00:00 premium: 2.633348313466808 option type: c direction: l
# Option expires 2002-10-21 00:00:00 return: 2.529754638671875
# State: 0.0
# option invested on 2002-11-06 00:00:00 premium: 2.3210367316206835 option type: p direction: l
# Option expires 2002-12-09 00:00:00 return: 2.482013702392578
# State: 0.0
# option invested on 2002-12-13 00:00:00 premium: 2.044985214756565 option type: c direction: l
# Option expires 2003-01-13 00:00:00 return: 2.90777587890625
# State: 0.0
# option invested on 2003-01-24 00:00:00 premium: 2.220086177264349 option type: c direction: l
# Option expires 2003-02-24 00:00:00 return: 0
# State: 0.0
# option invested on 2003-03-10 00:00:00 premium: 2.2086578022037315 option type: c direction: l
# Option expires 2003-04-10 00:00:00 return: 4.610023498535156
# State: 0.0
# option invested on 2003-04-15 00:00:00 premium: 1.6627769341334435 option type: p direction: l
# Option expires 2003-05-16 00:00:00 return: 0
# State: 0.0
# option invested on 2003-05-27 00:00:00 premium: 1.5672530713659398 option type: p direction: l
# Option expires 2003-06-27 00:00:00 return: 0
# State: 0.0
# option invested on 2003-08-05 00:00:00 premium: 1.801657734831707 option type: c direction: l
# Option expires 2003-09-05 00:00:00 return: 4.551017761230469
# State: 0.0
# option invested on 2003-09-08 00:00:00 premium: 1.5628627522887797 option type: p direction: l
# Option expires 2003-10-09 00:00:00 return: 0
# State: 0.0
# option invested on 2003-11-03 00:00:00 premium: 1.4551364288878048 option type: p direction: l
# Option expires 2003-12-04 00:00:00 return: 0
# State: 0.0
# option invested on 2003-12-18 00:00:00 premium: 1.471241697392621 option type: p direction: l
# Option expires 2004-01-20 00:00:00 return: 0
# State: 0.0
# option invested on 2004-01-21 00:00:00 premium: 1.3780059325231448 option type: p direction: l
# Option expires 2004-02-23 00:00:00 return: 0.36516571044921875
# State: 0.0
# option invested on 2004-03-05 00:00:00 premium: 1.4067606018875054 option type: p direction: l
# Option expires 2004-04-05 00:00:00 return: 0.5054702758789062
# State: 0.0
# option invested on 2004-04-06 00:00:00 premium: 1.473574356115094 option type: p direction: l
# Option expires 2004-05-07 00:00:00 return: 3.5498504638671875
# State: 0.0
# option invested on 2004-05-10 00:00:00 premium: 1.7962854384857607 option type: c direction: l
# Option expires 2004-06-10 00:00:00 return: 3.9665756225585938
# State: 0.0
# option invested on 2004-06-23 00:00:00 premium: 1.3493693120570782 option type: p direction: l
# Option expires 2004-07-26 00:00:00 return: 4.327293395996094
# State: 0.0
# option invested on 2004-08-05 00:00:00 premium: 1.6652485930484247 option type: c direction: l
# Option expires 2004-09-07 00:00:00 return: 3.2166061401367188
# State: 0.0
# option invested on 2004-09-13 00:00:00 premium: 1.2575689904703324 option type: p direction: l
# Option expires 2004-10-14 00:00:00 return: 1.6800079345703125
# State: 0.0
# option invested on 2004-10-22 00:00:00 premium: 1.417979633231198 option type: c direction: l
# Option expires 2004-11-22 00:00:00 return: 6.0396881103515625
# State: 0.0
# option invested on 2004-12-02 00:00:00 premium: 1.313467715758847 option type: p direction: l
# Option expires 2005-01-03 00:00:00 return: 0
# State: 0.0
# option invested on 2005-01-05 00:00:00 premium: 1.4151174366152972 option type: c direction: l
# Option expires 2005-02-07 00:00:00 return: 1.5033493041992188
# State: 0.0
# option invested on 2005-02-08 00:00:00 premium: 1.190040102510963 option type: p direction: l
# Option expires 2005-03-11 00:00:00 return: 0
# State: 0.0
# option invested on 2005-03-16 00:00:00 premium: 1.3683863252522315 option type: c direction: l
# Option expires 2005-04-18 00:00:00 return: 0
# State: 0.0
# option invested on 2005-04-20 00:00:00 premium: 1.641594983770183 option type: c direction: l
# Option expires 2005-05-23 00:00:00 return: 4.381324768066406
# State: 0.0
# option invested on 2005-05-24 00:00:00 premium: 1.297515525957074 option type: p direction: l
# Option expires 2005-06-24 00:00:00 return: 0.02915191650390625
# State: 0.0
# option invested on 2005-07-11 00:00:00 premium: 1.183756363276565 option type: p direction: l
# Option expires 2005-08-11 00:00:00 return: 0
# State: 0.0
# option invested on 2005-08-16 00:00:00 premium: 1.4181892925923734 option type: c direction: l
# Option expires 2005-09-16 00:00:00 return: 1.3356781005859375
# State: 0.0
# option invested on 2005-10-05 00:00:00 premium: 1.4989429535119072 option type: c direction: l
# Option expires 2005-11-07 00:00:00 return: 1.9207077026367188
# State: 0.0
# option invested on 2005-11-10 00:00:00 premium: 1.2674753014918423 option type: p direction: l
# Option expires 2005-12-12 00:00:00 return: 0
# State: 0.0
# option invested on 2005-12-14 00:00:00 premium: 1.1590679296447917 option type: p direction: l
# Option expires 2006-01-17 00:00:00 return: 0
# State: 0.0
# option invested on 2006-02-03 00:00:00 premium: 1.4188909228827384 option type: c direction: l
# Option expires 2006-03-06 00:00:00 return: 1.4110565185546875
# State: 0.0
# option invested on 2006-03-14 00:00:00 premium: 1.2157553669455652 option type: p direction: l
# Option expires 2006-04-17 00:00:00 return: 0.7488555908203125
# State: 0.0
# option invested on 2006-04-20 00:00:00 premium: 1.3307948573211448 option type: p direction: l
# Option expires 2006-05-22 00:00:00 return: 3.7281112670898438
# State: 0.0
# option invested on 2006-05-23 00:00:00 premium: 1.9814889483924247 option type: c direction: l
# Option expires 2006-06-23 00:00:00 return: 0
# State: 0.0
# option invested on 2006-06-29 00:00:00 premium: 1.4498410825767252 option type: p direction: l
# Option expires 2006-07-31 00:00:00 return: 0
# State: 0.0
# option invested on 2006-08-16 00:00:00 premium: 1.4081984063620254 option type: p direction: l
# Option expires 2006-09-18 00:00:00 return: 0
# State: 0.0
# option invested on 2006-09-20 00:00:00 premium: 1.3279988329661663 option type: p direction: l
# Option expires 2006-10-23 00:00:00 return: 0
# State: 0.0
# option invested on 2006-10-24 00:00:00 premium: 1.3089871969909197 option type: p direction: l
# Option expires 2006-11-24 00:00:00 return: 0
# State: 0.0
# option invested on 2006-12-04 00:00:00 premium: 1.3964154753402127 option type: p direction: l
# Option expires 2007-01-04 00:00:00 return: 0
# State: 0.0
# option invested on 2007-01-12 00:00:00 premium: 1.2888734365292578 option type: p direction: l
# Option expires 2007-02-12 00:00:00 return: 0
# State: 0.0
# option invested on 2007-02-14 00:00:00 premium: 1.3203415740779292 option type: p direction: l
# Option expires 2007-03-19 00:00:00 return: 3.6714630126953125
# State: 0.0
# option invested on 2007-03-23 00:00:00 premium: 1.6463193044813238 option type: p direction: l
# Option expires 2007-04-23 00:00:00 return: 0
# State: 0.0
# option invested on 2007-04-25 00:00:00 premium: 1.7502150365932891 option type: p direction: l
# Option expires 2007-05-29 00:00:00 return: 0
# State: 0.0
# option invested on 2007-05-30 00:00:00 premium: 1.746066164332511 option type: p direction: l
# Option expires 2007-07-02 00:00:00 return: 0.7865676879882812
# State: 0.0
# option invested on 2007-07-12 00:00:00 premium: 2.131306776059091 option type: p direction: l
# Option expires 2007-08-13 00:00:00 return: 6.986106872558594
# State: 0.0
# option invested on 2007-08-15 00:00:00 premium: 3.81980073939944 option type: c direction: l
# Option expires 2007-09-17 00:00:00 return: 5.384468078613281
# State: 0.0
# option invested on 2007-09-18 00:00:00 premium: 2.74839864913541 option type: p direction: l
# Option expires 2007-10-19 00:00:00 return: 1.586334228515625
# State: 0.0
# option invested on 2007-10-22 00:00:00 premium: 2.8979196915949075 option type: c direction: l
# Option expires 2007-11-23 00:00:00 return: 0
# State: 0.0
# option invested on 2007-11-26 00:00:00 premium: 3.616801940423983 option type: c direction: l
# Option expires 2007-12-27 00:00:00 return: 5.7500152587890625
# State: 0.0
# option invested on 2008-01-04 00:00:00 premium: 3.0228006878117597 option type: c direction: l
# Option expires 2008-02-04 00:00:00 return: 0
# State: 0.0
# option invested on 2008-02-26 00:00:00 premium: 2.7094811805751036 option type: p direction: l
# Option expires 2008-03-28 00:00:00 return: 4.775398254394531
# State: 0.0
# option invested on 2008-04-01 00:00:00 premium: 2.7833855815130377 option type: p direction: l
# Option expires 2008-05-02 00:00:00 return: 0
# State: 0.0
# option invested on 2008-05-06 00:00:00 premium: 2.3284887507956142 option type: p direction: l
# Option expires 2008-06-06 00:00:00 return: 4.459228515625
# State: 0.0
# option invested on 2008-06-09 00:00:00 premium: 2.837143234930032 option type: c direction: l
# Option expires 2008-07-10 00:00:00 return: 0
# State: 0.0
# option invested on 2008-07-14 00:00:00 premium: 3.150081766921943 option type: c direction: l
# Option expires 2008-08-14 00:00:00 return: 5.306266784667969
# State: 0.0
# option invested on 2008-09-04 00:00:00 premium: 2.6896257583305925 option type: c direction: l
# Option expires 2008-10-06 00:00:00 return: 0
# State: 0.0
# option invested on 2008-10-08 00:00:00 premium: 5.064659556087321 option type: c direction: l
# Option expires 2008-11-10 00:00:00 return: 0
# State: 0.0
# option invested on 2008-11-19 00:00:00 premium: 5.456076955038455 option type: c direction: l
# Option expires 2008-12-22 00:00:00 return: 4.90399169921875
# State: 1.0
# option invested on 2009-01-02 00:00:00 premium: 3.3227254068976606 option type: c direction: s
# Option expires 2009-02-02 00:00:00 return: 0
# State: 0.0
# option invested on 2009-02-18 00:00:00 premium: 3.488939310406444 option type: c direction: l
# Option expires 2009-03-23 00:00:00 return: 2.980854034423828
# State: 0.0
# option invested on 2009-03-25 00:00:00 premium: 3.159773319070947 option type: p direction: l
# Option expires 2009-04-27 00:00:00 return: 0
# State: 0.0
# option invested on 2009-04-29 00:00:00 premium: 2.897720925581133 option type: p direction: l
# Option expires 2009-06-01 00:00:00 return: 0
# State: 0.0
# option invested on 2009-06-02 00:00:00 premium: 2.5860316746584786 option type: p direction: l
# Option expires 2009-07-06 00:00:00 return: 3.6093978881835938
# State: 0.0
# option invested on 2009-07-07 00:00:00 premium: 2.5132123981004355 option type: c direction: l
# Option expires 2009-08-07 00:00:00 return: 10.499313354492188
# State: 0.0
# option invested on 2009-08-21 00:00:00 premium: 2.38595473711883 option type: p direction: l
# Option expires 2009-09-21 00:00:00 return: 0
# State: 0.0
# option invested on 2009-10-14 00:00:00 premium: 2.32781042805955 option type: p direction: l
# Option expires 2009-11-16 00:00:00 return: 0
# State: 0.0
# option invested on 2009-11-17 00:00:00 premium: 2.324751555402564 option type: p direction: l
# Option expires 2009-12-18 00:00:00 return: 0.4308624267578125
# State: 0.0
# option invested on 2009-12-21 00:00:00 premium: 2.138499881582085 option type: p direction: l
# Option expires 2010-01-21 00:00:00 return: 0
# State: 0.0
# option invested on 2010-01-25 00:00:00 premium: 2.6101730877596268 option type: c direction: l
# Option expires 2010-02-25 00:00:00 return: 0.7264556884765625
# State: 0.0
# option invested on 2010-03-05 00:00:00 premium: 1.8687466787789972 option type: p direction: l
# Option expires 2010-04-05 00:00:00 return: 0
# State: 0.0
# option invested on 2010-04-06 00:00:00 premium: 1.822962138742568 option type: p direction: l
# Option expires 2010-05-07 00:00:00 return: 6.305595397949219
# State: 0.0
# option invested on 2010-05-18 00:00:00 premium: 3.5367475385369076 option type: c direction: l
# Option expires 2010-06-18 00:00:00 return: 0
# State: 0.0
# option invested on 2010-06-30 00:00:00 premium: 3.3590439297008317 option type: c direction: l
# Option expires 2010-08-02 00:00:00 return: 7.768806457519531
# State: 0.0
# option invested on 2010-08-04 00:00:00 premium: 2.371406502865568 option type: p direction: l
# Option expires 2010-09-07 00:00:00 return: 2.711761474609375
# State: 0.0
# option invested on 2010-09-09 00:00:00 premium: 2.3907415855347054 option type: p direction: l
# Option expires 2010-10-11 00:00:00 return: 0
# State: 0.0
# option invested on 2010-10-12 00:00:00 premium: 2.1077437986745196 option type: p direction: l
# Option expires 2010-11-12 00:00:00 return: 0
# State: 0.0
# option invested on 2010-12-03 00:00:00 premium: 2.1071285122287975 option type: p direction: l
# Option expires 2011-01-03 00:00:00 return: 0
# State: 0.0
# option invested on 2011-01-04 00:00:00 premium: 2.112927163148477 option type: p direction: l
# Option expires 2011-02-04 00:00:00 return: 0
# State: 0.0
# option invested on 2011-02-07 00:00:00 premium: 2.058443098644446 option type: p direction: l
# Option expires 2011-03-10 00:00:00 return: 1.6706924438476562
# State: 0.0
# option invested on 2011-03-14 00:00:00 premium: 2.6259609634487973 option type: c direction: l
# Option expires 2011-04-14 00:00:00 return: 1.7131118774414062
# State: 0.0
# option invested on 2011-04-26 00:00:00 premium: 2.026920828462977 option type: p direction: l
# Option expires 2011-05-27 00:00:00 return: 1.05804443359375
# State: 0.0
# option invested on 2011-06-01 00:00:00 premium: 2.3192513324368775 option type: c direction: l
# Option expires 2011-07-05 00:00:00 return: 2.1519622802734375
# State: 0.0
# option invested on 2011-07-06 00:00:00 premium: 2.116807325455966 option type: p direction: l
# Option expires 2011-08-08 00:00:00 return: 18.03411102294922
# State: 0.0
# option invested on 2011-08-09 00:00:00 premium: 3.958160235435507 option type: c direction: l
# Option expires 2011-09-09 00:00:00 return: 0
# State: 0.0
# option invested on 2011-09-23 00:00:00 premium: 4.519857357488924 option type: c direction: l
# Option expires 2011-10-24 00:00:00 return: 9.977981567382812
# State: 1.0
# option invested on 2011-10-27 00:00:00 premium: 3.170222105498098 option type: c direction: s
# Option expires 2011-11-28 00:00:00 return: 0
# State: 0.0
# option invested on 2012-01-03 00:00:00 premium: 2.8553377526322947 option type: p direction: l
# Option expires 2012-02-03 00:00:00 return: 0
# State: 0.0
# option invested on 2012-02-06 00:00:00 premium: 2.333576399714616 option type: p direction: l
# Option expires 2012-03-08 00:00:00 return: 0
# State: 0.0
# option invested on 2012-03-13 00:00:00 premium: 2.029970254808987 option type: p direction: l
# Option expires 2012-04-13 00:00:00 return: 1.9486007690429688
# State: 0.0
# option invested on 2012-05-09 00:00:00 premium: 2.672184374246072 option type: c direction: l
# Option expires 2012-06-11 00:00:00 return: 0
# State: 0.0
# option invested on 2012-06-15 00:00:00 premium: 2.7892613955371246 option type: p direction: l
# Option expires 2012-07-16 00:00:00 return: 0
# State: 0.0
# option invested on 2012-07-27 00:00:00 premium: 2.2865324726013085 option type: p direction: l
# Option expires 2012-08-27 00:00:00 return: 0
# State: 0.0
# option invested on 2012-09-06 00:00:00 premium: 2.2160297813310095 option type: p direction: l
# Option expires 2012-10-08 00:00:00 return: 0
# State: 0.0
# option invested on 2012-10-10 00:00:00 premium: 2.317318799208394 option type: c direction: l
# Option expires 2012-11-12 00:00:00 return: 0
# State: 0.0
# option invested on 2012-11-13 00:00:00 premium: 2.277222089975311 option type: c direction: l
# Option expires 2012-12-14 00:00:00 return: 3.67584228515625
# State: 0.0
# option invested on 2012-12-17 00:00:00 premium: 2.3323008460996704 option type: p direction: l
# Option expires 2013-01-17 00:00:00 return: 0
# State: 0.0
# option invested on 2013-01-29 00:00:00 premium: 2.010076267745461 option type: p direction: l
# Option expires 2013-03-01 00:00:00 return: 0
# State: 0.0
# option invested on 2013-03-05 00:00:00 premium: 2.084440956929754 option type: p direction: l
# Option expires 2013-04-05 00:00:00 return: 0
# State: 0.0
# option invested on 2013-04-09 00:00:00 premium: 2.0274647366168352 option type: p direction: l
# Option expires 2013-05-10 00:00:00 return: 0
# State: 0.0
# option invested on 2013-05-14 00:00:00 premium: 2.1256620388144825 option type: p direction: l
# Option expires 2013-06-14 00:00:00 return: 1.7686309814453125
# State: 0.0
# option invested on 2013-06-21 00:00:00 premium: 3.0306826550545622 option type: c direction: l
# Option expires 2013-07-22 00:00:00 return: 9.045867919921875
# State: 0.0
# option invested on 2013-08-02 00:00:00 premium: 2.076054346956127 option type: p direction: l
# Option expires 2013-09-03 00:00:00 return: 5.6894378662109375
# State: 0.0
# option invested on 2013-09-10 00:00:00 premium: 2.480707631331356 option type: p direction: l
# Option expires 2013-10-11 00:00:00 return: 0
# State: 0.0
# option invested on 2013-10-16 00:00:00 premium: 2.5711096857708213 option type: p direction: l
# Option expires 2013-11-18 00:00:00 return: 0
# State: 0.0
# option invested on 2013-11-21 00:00:00 premium: 2.318252002620227 option type: p direction: l
# Option expires 2013-12-23 00:00:00 return: 0
# State: 0.0
# option invested on 2013-12-24 00:00:00 premium: 2.336750691502303 option type: p direction: l
# Option expires 2014-01-24 00:00:00 return: 3.5400848388671875
# State: 0.0
# option invested on 2014-01-27 00:00:00 premium: 3.1608666747672913 option type: c direction: l
# Option expires 2014-02-27 00:00:00 return: 6.843505859375
# State: 0.0
# option invested on 2014-03-06 00:00:00 premium: 2.7321895405302143 option type: p direction: l
# Option expires 2014-04-07 00:00:00 return: 2.6518707275390625
# State: 0.0
# option invested on 2014-04-10 00:00:00 premium: 2.98277753806957 option type: c direction: l
# Option expires 2014-05-12 00:00:00 return: 5.8351593017578125
# State: 0.0
# option invested on 2014-05-13 00:00:00 premium: 2.3699020188750666 option type: p direction: l
# Option expires 2014-06-13 00:00:00 return: 0
# State: 0.0
# option invested on 2014-06-20 00:00:00 premium: 2.200900548144901 option type: p direction: l
# Option expires 2014-07-21 00:00:00 return: 0
# State: 0.0
# option invested on 2014-07-23 00:00:00 premium: 2.366714117306117 option type: p direction: l
# Option expires 2014-08-25 00:00:00 return: 0
# State: 0.0
# option invested on 2014-08-26 00:00:00 premium: 2.4092832051972835 option type: p direction: l
# Option expires 2014-09-26 00:00:00 return: 1.3308563232421875
# State: 0.0
# option invested on 2014-09-30 00:00:00 premium: 3.3235575535874773 option type: c direction: l
# Option expires 2014-10-31 00:00:00 return: 4.122467041015625
# State: 0.0
# option invested on 2014-11-03 00:00:00 premium: 3.0776560227189407 option type: p direction: l
# Option expires 2014-12-04 00:00:00 return: 0
# State: 0.0
# option invested on 2014-12-10 00:00:00 premium: 3.888356736387834 option type: c direction: l
# Option expires 2015-01-12 00:00:00 return: 0.540557861328125
# State: 0.0
# option invested on 2015-01-15 00:00:00 premium: 4.619993200612598 option type: c direction: l
# Option expires 2015-02-17 00:00:00 return: 9.907501220703125
# State: 0.0
# option invested on 2015-02-18 00:00:00 premium: 3.378445083530792 option type: p direction: l
# Option expires 2015-03-23 00:00:00 return: 0
# State: 0.0
# option invested on 2015-04-23 00:00:00 premium: 2.762343885221725 option type: p direction: l
# Option expires 2015-05-26 00:00:00 return: 0.4128265380859375
# State: 0.0
# option invested on 2015-06-05 00:00:00 premium: 3.1190284441757683 option type: c direction: l
# Option expires 2015-07-06 00:00:00 return: 0
# State: 0.0
# option invested on 2015-07-08 00:00:00 premium: 4.212846454199521 option type: c direction: l
# Option expires 2015-08-10 00:00:00 return: 5.4464263916015625
# State: 0.0
# option invested on 2015-08-20 00:00:00 premium: 4.091235953579655 option type: c direction: l
# Option expires 2015-09-21 00:00:00 return: 0
# State: 0.0
# option invested on 2015-09-28 00:00:00 premium: 5.455604375439847 option type: c direction: l
# Option expires 2015-10-29 00:00:00 return: 18.871505737304688
# State: 0.0
# option invested on 2015-11-02 00:00:00 premium: 3.146635601680103 option type: p direction: l
# Option expires 2015-12-03 00:00:00 return: 4.332672119140625
# State: 0.0
# option invested on 2015-12-11 00:00:00 premium: 5.175927668248022 option type: c direction: l
# Option expires 2016-01-11 00:00:00 return: 0
# State: 0.0
# option invested on 2016-01-12 00:00:00 premium: 4.604591917445546 option type: c direction: l
# Option expires 2016-02-12 00:00:00 return: 0
# State: 0.0
# option invested on 2016-02-22 00:00:00 premium: 3.999644280452742 option type: p direction: l
# Option expires 2016-03-24 00:00:00 return: 0
# State: 0.0
# option invested on 2016-03-30 00:00:00 premium: 2.9873635815756785 option type: p direction: l
# Option expires 2016-05-02 00:00:00 return: 0
# State: 0.0
# option invested on 2016-05-13 00:00:00 premium: 3.2888043334466346 option type: c direction: l
# Option expires 2016-06-13 00:00:00 return: 3.3819580078125
# State: 0.0
# option invested on 2016-06-24 00:00:00 premium: 5.59140422682114 option type: c direction: l
# Option expires 2016-07-25 00:00:00 return: 12.35430908203125
# State: 0.0
# option invested on 2016-08-05 00:00:00 premium: 2.678035889271257 option type: p direction: l
# Option expires 2016-09-06 00:00:00 return: 0
# State: 0.0
# option invested on 2016-09-09 00:00:00 premium: 3.9998400408229315 option type: c direction: l
# Option expires 2016-10-10 00:00:00 return: 3.6592254638671875
# State: 0.0
# option invested on 2016-10-13 00:00:00 premium: 3.8310715752939615 option type: c direction: l
# Option expires 2016-11-14 00:00:00 return: 3.3148345947265625
# State: 0.0
# option invested on 2016-11-15 00:00:00 premium: 3.15346452948431 option type: p direction: l
# Option expires 2016-12-16 00:00:00 return: 0
# State: 0.0
# option invested on 2017-01-06 00:00:00 premium: 2.8024297138349823 option type: p direction: l
# Option expires 2017-02-06 00:00:00 return: 0
# State: 0.0
# option invested on 2017-02-09 00:00:00 premium: 2.7354548854593332 option type: p direction: l
# Option expires 2017-03-13 00:00:00 return: 0
# State: 0.0
# option invested on 2017-03-15 00:00:00 premium: 3.02665330191266 option type: p direction: l
# Option expires 2017-04-17 00:00:00 return: 3.1290435791015625
# State: 0.0
# option invested on 2017-04-24 00:00:00 premium: 2.8154140401238834 option type: p direction: l
# Option expires 2017-05-25 00:00:00 return: 0
# State: 0.0
# option invested on 2017-05-26 00:00:00 premium: 2.6012145586960713 option type: p direction: l
# Option expires 2017-06-26 00:00:00 return: 0
# State: 0.0
# option invested on 2017-06-27 00:00:00 premium: 2.936219101924692 option type: c direction: l
# Option expires 2017-07-28 00:00:00 return: 5.245208740234375
# State: 0.0
# option invested on 2017-08-10 00:00:00 premium: 4.279314386434237 option type: c direction: l
# Option expires 2017-09-11 00:00:00 return: 5.12298583984375
# State: 0.0
# option invested on 2017-09-12 00:00:00 premium: 2.9124361126221885 option type: p direction: l
# Option expires 2017-10-13 00:00:00 return: 0
# State: 0.0
# option invested on 2017-10-20 00:00:00 premium: 2.838972978602868 option type: p direction: l
# Option expires 2017-11-20 00:00:00 return: 0
# State: 0.0
# option invested on 2017-11-21 00:00:00 premium: 2.8029173173493263 option type: p direction: l
# Option expires 2017-12-22 00:00:00 return: 0
# State: 0.0
# option invested on 2018-01-03 00:00:00 premium: 2.7593391550311424 option type: p direction: l
# Option expires 2018-02-05 00:00:00 return: 6.2097015380859375
# State: 0.0
# option invested on 2018-02-06 00:00:00 premium: 8.871533711760378 option type: c direction: l
# Option expires 2018-03-09 00:00:00 return: 9.248062133789062
# State: 0.0
# option invested on 2018-03-12 00:00:00 premium: 4.859778127447214 option type: p direction: l
# Option expires 2018-04-12 00:00:00 return: 10.942840576171875
# State: 0.0
# option invested on 2018-04-17 00:00:00 premium: 4.576177611312417 option type: p direction: l
# Option expires 2018-05-18 00:00:00 return: 0
# State: 0.0
# option invested on 2018-06-04 00:00:00 premium: 3.8987797645835656 option type: p direction: l
# Option expires 2018-07-05 00:00:00 return: 0.537353515625
# State: 0.0
# option invested on 2018-07-10 00:00:00 premium: 3.9425281373694077 option type: p direction: l
# Option expires 2018-08-10 00:00:00 return: 0
# State: 0.0
# option invested on 2018-08-21 00:00:00 premium: 4.11713927934548 option type: p direction: l
# Option expires 2018-09-21 00:00:00 return: 0
# State: 0.0
# option invested on 2018-10-09 00:00:00 premium: 5.134404946197606 option type: c direction: l
# Option expires 2018-11-09 00:00:00 return: 0
# State: 0.0
# option invested on 2018-11-23 00:00:00 premium: 6.326327827213817 option type: c direction: l
# Option expires 2018-12-24 00:00:00 return: 0
# State: 0.0
# option invested on 2019-01-18 00:00:00 premium: 5.337085395946346 option type: p direction: l
# Option expires 2019-02-19 00:00:00 return: 0
# State: 0.0
# option invested on 2019-02-20 00:00:00 premium: 4.404413473542263 option type: p direction: l
# Option expires 2019-03-25 00:00:00 return: 0
# State: 0.0
# option invested on 2019-04-01 00:00:00 premium: 4.343472929191876 option type: p direction: l
# Option expires 2019-05-02 00:00:00 return: 0
# State: 0.0
# option invested on 2019-05-03 00:00:00 premium: 4.293753038310086 option type: p direction: l
# Option expires 2019-06-03 00:00:00 return: 18.9111328125
# State: 0.0
# option invested on 2019-06-10 00:00:00 premium: 5.212239552106865 option type: p direction: l
# Option expires 2019-07-11 00:00:00 return: 0
# State: 0.0
# option invested on 2019-07-12 00:00:00 premium: 4.249556568381337 option type: p direction: l
# Option expires 2019-08-12 00:00:00 return: 12.284576416015625
# State: 0.0
# option invested on 2019-08-14 00:00:00 premium: 7.111218512953002 option type: c direction: l
# Option expires 2019-09-16 00:00:00 return: 15.878204345703125
# State: 0.0
# option invested on 2019-10-01 00:00:00 premium: 6.207059852798352 option type: c direction: l
# Option expires 2019-11-01 00:00:00 return: 12.655303955078125
# State: 0.0
# option invested on 2019-11-04 00:00:00 premium: 4.517333655074367 option type: p direction: l
# Option expires 2019-12-05 00:00:00 return: 0
# State: 0.0
# option invested on 2019-12-06 00:00:00 premium: 4.908466769444601 option type: p direction: l
# pf end value: -75.8726087276969

# %%
pf_df.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-fd1fe0c28f73> in <module>()
# ----> 1 pf_df.plot()
#
# NameError: name 'pf_df' is not defined

# %%
# Object-oriented solution

# %%
class option:
    def __init__(self, opt_type, opt_dir, opt_strike, opt_exp, opt_reg):
        self.opt_type = opt_type
        self.opt_dir = opt_dir
        self.opt_strike = opt_strike
        self.opt_exp = opt_exp
        self.opt_reg = opt_reg
        self.state = 'invested'
    
    def option_payout(self, S):
        """
        Calculates an option pay-out depending on direction (long/short),
        option type (call/put), current underlying level (S) and the option's strike (K)
        """
        setattr(self, 'state', 'expired')        
        if self.opt_dir == "s":
            if self.opt_type == "p":
                return -max(0, self.opt_strike-S)
            else:
                return -max(0, S-self.opt_strike)
        else:
            if self.opt_type == "p":
                return max(0, self.opt_strike-S)
            else:
                return max(0, S-self.opt_strike)

    def option_premium(self, vola, cur_date, cur_close):
        if self.opt_type == "p":
            prem = Put(vola, timediff(self.opt_exp, cur_date), cur_close, self.opt_strike, 0.005)
        else:
            prem = Call(vola, timediff(self.opt_exp, cur_date), cur_close, self.opt_strike, 0.005)
        if self.opt_dir == "l":
            return -prem
        else:
            return prem
    
    pass

# %%
a = option ("p", "l", 50, 40)

# %%
def timediff(date1, date2):
    """
    Little helper function to calculate 30/360 yearfrac for calculating
    """
    return (date1.day + date1.month * 30 + date1.year * 360 - (date2.day + date2.month * 30 + date2.year * 360))/360

# %%
# Initial investment state = 0 (not invested)
inv_state = 0

# Setting initial portfolio value to 0
pf_value = 0

# Creating list to keep track of portfolio values
pf_value_list = []

# Create portfolio dataframe with underlyings date index
pf_df = pd.DataFrame(index=spy_df.index)

# Looping through the data and short put options

for day in range(len(spy_df)):
    # Keeping track of every day's portfolio value
    pf_value_list.append(pf_value)
    cur_close = spy_df["Adj Close"].iloc[day]
    
    # Set regime state according to smoothed marginal probabilities
    # (0 = low vol | 1 = high vol)
    if spy_df.index[day] >= res_spy_df.smoothed_marginal_probabilities.index[0]:
        reg_state = round(res_spy_df.smoothed_marginal_probabilities.loc[spy_df.index[day]][0])

    # Expiry of options
    if inv_state == 1 and spy_df.index[day] > new_option.opt_exp:
        # Calculating option premium at expiry
        opt_return = new_option.option_payout(spy_df["Adj Close"].iloc[day])
        print("Option expires", spy_df.index[day], "return:", opt_return)

        # Adding expiry value to portfolio value
        pf_value += opt_return

        # Setting investment state to "not invested" = 0
        inv_state = 0

    # High vol and above upper band -> short call
    if cur_close > spy_df["Upper Band"].iloc[day] and reg_state == 1:
        print("State:", reg_state)
        
        if inv_state == 1 and new_option.opt_reg != reg_state:
            #Book out existing option
            pf_value -= new_option.option_premium(vix_df["Adj Close"].loc[spy_df.index[day]] / 100, spy_df.index[day], cur_close)
            
            # Create new option
            new_option = option("c", "s", cur_close, spy_df.index[day] + dt.timedelta(days=30), reg_state)
            opt_prem = new_option.option_premium(vix_df["Adj Close"].loc[spy_df.index[day]] / 100, spy_df.index[day], cur_close)
            pf_value += opt_prem
        elif inv_state == 0:
            # Create new option
            new_option = option("c", "s", cur_close, spy_df.index[day] + dt.timedelta(days=30), reg_state)
            opt_prem = new_option.option_premium(vix_df["Adj Close"].loc[spy_df.index[day]] / 100, spy_df.index[day], cur_close)
            pf_value += opt_prem
            # Set invested state to 1 = invested
            inv_state = 1

            # Adding option premium to portfolio value
            pf_value += opt_prem

        print("option invested on", spy_df.index[day], "premium:", opt_prem, "option type:", new_option.opt_type, "direction:", new_option.opt_dir)

    # High vol and below lower band -> short put      
    if cur_close > spy_df["Upper Band"].iloc[day] and inv_state == 0 and reg_state == 1:
        print("State:", reg_state)
        
        if inv_state == 1 and new_option.opt_reg != reg_state:
            #Book out existing option
            pf_value -= new_option.option_premium(vix_df["Adj Close"].loc[spy_df.index[day]] / 100, spy_df.index[day], cur_close)
            
            # Create new option
            new_option = option("p", "s", cur_close, spy_df.index[day] + dt.timedelta(days=30), reg_state)
            opt_prem = new_option.option_premium(vix_df["Adj Close"].loc[spy_df.index[day]] / 100, spy_df.index[day], cur_close)
            pf_value += opt_prem
        elif inv_state == 0:
            # Create new option
            new_option = option("p", "s", cur_close, spy_df.index[day] + dt.timedelta(days=30), reg_state)
            opt_prem = new_option.option_premium(vix_df["Adj Close"].loc[spy_df.index[day]] / 100, spy_df.index[day], cur_close)

            # Set invested state to 1 = invested
            inv_state = 1

            # Adding option premium to portfolio value
            pf_value += opt_prem

        print("option invested on", spy_df.index[day], "premium:", opt_prem, "option type:", new_option.opt_type, "direction:", new_option.opt_dir)

    # Low vol and below lower band -> long call      
    if cur_close < spy_df["Lower Band"].iloc[day] and inv_state == 0 and reg_state == 0:
        print("State:", reg_state)
        
        if inv_state == 1 and new_option.opt_reg != reg_state:
            #Book out existing option
            pf_value -= new_option.option_premium(vix_df["Adj Close"].loc[spy_df.index[day]] / 100, spy_df.index[day], cur_close)
            
            # Create new option
            new_option = option("c", "l", cur_close, spy_df.index[day] + dt.timedelta(days=30), reg_state)
            opt_prem = new_option.option_premium(vix_df["Adj Close"].loc[spy_df.index[day]] / 100, spy_df.index[day], cur_close)
            pf_value -= opt_prem
        elif inv_state == 0:
            # Create new option
            new_option = option("c", "l", cur_close, spy_df.index[day] + dt.timedelta(days=30), reg_state)
            opt_prem = new_option.option_premium(vix_df["Adj Close"].loc[spy_df.index[day]] / 100, spy_df.index[day], cur_close)

            # Set invested state to 1 = invested
            inv_state = 1

            # Adding option premium to portfolio value
            pf_value += opt_prem

        print("option invested on", spy_df.index[day], "premium:", opt_prem, "option type:", new_option.opt_type, "direction:", new_option.opt_dir)

    # Low vol and above upper band -> long put      
    if cur_close > spy_df["Upper Band"].iloc[day] and inv_state == 0 and reg_state == 0:
        print("State:", reg_state)
        
        if inv_state == 1 and new_option.opt_reg != reg_state:
            #Book out existing option
            pf_value -= new_option.option_premium(vix_df["Adj Close"].loc[spy_df.index[day]] / 100, spy_df.index[day], cur_close)
            
            # Create new option
            new_option = option("p", "l", cur_close, spy_df.index[day] + dt.timedelta(days=30), reg_state)
            opt_prem = new_option.option_premium(vix_df["Adj Close"].loc[spy_df.index[day]] / 100, spy_df.index[day], cur_close)
            pf_value += opt_prem
        elif inv_state == 0:
            # Create new option
            new_option = option("p", "l", cur_close, spy_df.index[day] + dt.timedelta(days=30), reg_state)
            opt_prem = new_option.option_premium(vix_df["Adj Close"].loc[spy_df.index[day]] / 100, spy_df.index[day], cur_close)

            # Set invested state to 1 = invested
            inv_state = 1

            # Adding option premium to portfolio value
            pf_value -= opt_prem

        print("option invested on", spy_df.index[day], "premium:", opt_prem, "option type:", new_option.opt_type, "direction:", new_option.opt_dir)        

print("pf end value:", pf_value)

# Adding each day's portfolio value to the portfolio dataframe
pf_df["Value"] = pf_value_list
# Out:
# State: 0.0
# option invested on 2000-02-18 00:00:00 premium: -2.8097298443705085 option type: c direction: l
# State: 1.0
# option invested on 2000-03-16 00:00:00 premium: 2.3516669810291404 option type: c direction: s
# Option expires 2000-04-17 00:00:00 return: 0
# State: 0.0
# option invested on 2000-04-17 00:00:00 premium: -3.206693394041352 option type: c direction: l
# Option expires 2000-05-18 00:00:00 return: 1.7835464477539062
# State: 0.0
# option invested on 2000-05-23 00:00:00 premium: -2.764250564941797 option type: c direction: l
# Option expires 2000-06-23 00:00:00 return: 4.562347412109375
# State: 0.0
# option invested on 2000-06-29 00:00:00 premium: -2.247572667600231 option type: c direction: l
# Option expires 2000-07-31 00:00:00 return: 0
# State: 0.0
# option invested on 2000-07-31 00:00:00 premium: -2.3058932308697706 option type: c direction: l
# Option expires 2000-08-31 00:00:00 return: 6.363372802734375
# State: 0.0
# option invested on 2000-08-31 00:00:00 premium: -1.9568933075779924 option type: p direction: l
# Option expires 2000-10-02 00:00:00 return: 5.542633056640625
# State: 0.0
# option invested on 2000-10-06 00:00:00 premium: -2.4950445849848677 option type: c direction: l
# Option expires 2000-11-06 00:00:00 return: 1.8561935424804688
# State: 0.0
# option invested on 2000-11-06 00:00:00 premium: -2.75048522814901 option type: p direction: l
# Option expires 2000-12-07 00:00:00 return: 6.912750244140625
# State: 0.0
# option invested on 2000-12-19 00:00:00 premium: -2.7559773929992843 option type: c direction: l
# Option expires 2001-01-19 00:00:00 return: 2.7393646240234375
# State: 0.0
# option invested on 2001-01-23 00:00:00 premium: -2.2547183376328803 option type: p direction: l
# Option expires 2001-02-23 00:00:00 return: 7.539207458496094
# State: 0.0
# option invested on 2001-02-23 00:00:00 premium: -2.7873041794198343 option type: c direction: l
# Option expires 2001-03-26 00:00:00 return: 0
# State: 0.0
# option invested on 2001-04-12 00:00:00 premium: -2.4369202338429403 option type: p direction: l
# State: 1.0
# option invested on 2001-04-18 00:00:00 premium: 2.383018461461482 option type: c direction: s
# Option expires 2001-05-21 00:00:00 return: -5.253135681152344
# State: 0.0
# option invested on 2001-05-21 00:00:00 premium: -2.1061238322038704 option type: p direction: l
# Option expires 2001-06-21 00:00:00 return: 5.134910583496094
# State: 0.0
# option invested on 2001-07-09 00:00:00 premium: -2.1140124798616 option type: c direction: l
# Option expires 2001-08-09 00:00:00 return: 0
# State: 0.0
# option invested on 2001-08-17 00:00:00 premium: -2.1856248649469734 option type: c direction: l
# Option expires 2001-09-17 00:00:00 return: 0
# State: 0.0
# option invested on 2001-09-17 00:00:00 premium: -3.466413055581093 option type: c direction: l
# Option expires 2001-10-18 00:00:00 return: 2.426116943359375
# State: 0.0
# option invested on 2001-10-25 00:00:00 premium: -2.532814731197348 option type: p direction: l
# Option expires 2001-11-26 00:00:00 return: 0
# State: 0.0
# option invested on 2001-12-05 00:00:00 premium: -2.0980744724196967 option type: p direction: l
# Option expires 2002-01-07 00:00:00 return: 0.1439666748046875
# State: 0.0
# option invested on 2002-01-16 00:00:00 premium: -2.092741649114714 option type: c direction: l
# Option expires 2002-02-19 00:00:00 return: 0
# State: 0.0
# option invested on 2002-03-01 00:00:00 premium: -1.7964114808558946 option type: p direction: l
# Option expires 2002-04-01 00:00:00 return: 0
# State: 0.0
# option invested on 2002-04-03 00:00:00 premium: -1.8465757942423693 option type: c direction: l
# Option expires 2002-05-06 00:00:00 return: 0
# State: 0.0
# option invested on 2002-05-07 00:00:00 premium: -1.8302237938031283 option type: c direction: l
# Option expires 2002-06-07 00:00:00 return: 0
# State: 0.0
# option invested on 2002-06-07 00:00:00 premium: -1.9604376921759936 option type: c direction: l
# Option expires 2002-07-08 00:00:00 return: 0
# State: 0.0
# option invested on 2002-07-11 00:00:00 premium: -2.49622698171925 option type: c direction: l
# Option expires 2002-08-12 00:00:00 return: 0
# State: 0.0
# option invested on 2002-08-15 00:00:00 premium: -2.160646298616008 option type: p direction: l
# Option expires 2002-09-16 00:00:00 return: 2.51983642578125
# State: 0.0
# option invested on 2002-09-18 00:00:00 premium: -2.633348313466808 option type: c direction: l
# Option expires 2002-10-21 00:00:00 return: 2.529754638671875
# State: 0.0
# option invested on 2002-10-21 00:00:00 premium: -2.356157148534944 option type: p direction: l
# Option expires 2002-11-21 00:00:00 return: 0
# State: 1.0
# option invested on 2002-11-21 00:00:00 premium: 1.8220087389306983 option type: c direction: s
# Option expires 2002-12-23 00:00:00 return: 0
# State: 0.0
# option invested on 2002-12-27 00:00:00 premium: -2.071390435997621 option type: c direction: l
# Option expires 2003-01-27 00:00:00 return: 0
# State: 0.0
# option invested on 2003-01-27 00:00:00 premium: -2.368654531976219 option type: c direction: l
# Option expires 2003-02-27 00:00:00 return: 0
# State: 0.0
# option invested on 2003-03-10 00:00:00 premium: -2.1713797661660514 option type: c direction: l
# Option expires 2003-04-10 00:00:00 return: 4.610023498535156
# State: 0.0
# option invested on 2003-04-15 00:00:00 premium: -1.6363185709046668 option type: p direction: l
# Option expires 2003-05-16 00:00:00 return: 0
# State: 0.0
# option invested on 2003-05-27 00:00:00 premium: -1.5135173181313277 option type: p direction: l
# Option expires 2003-06-27 00:00:00 return: 0
# State: 0.0
# option invested on 2003-08-05 00:00:00 premium: -1.7711615544933252 option type: c direction: l
# Option expires 2003-09-05 00:00:00 return: 4.551017761230469
# State: 0.0
# option invested on 2003-09-08 00:00:00 premium: -1.5321976528507975 option type: p direction: l
# Option expires 2003-10-09 00:00:00 return: 0
# State: 0.0
# option invested on 2003-11-03 00:00:00 premium: -1.4236677687662933 option type: p direction: l
# Option expires 2003-12-04 00:00:00 return: 0
# State: 0.0
# option invested on 2003-12-04 00:00:00 premium: -1.3995801562530303 option type: p direction: l
# Option expires 2004-01-05 00:00:00 return: 0
# State: 0.0
# option invested on 2004-01-05 00:00:00 premium: -1.5778787979160853 option type: p direction: l
# Option expires 2004-02-05 00:00:00 return: 0
# State: 0.0
# option invested on 2004-02-11 00:00:00 premium: -1.4792077944412796 option type: p direction: l
# Option expires 2004-03-15 00:00:00 return: 3.4873046875
# State: 0.0
# option invested on 2004-03-15 00:00:00 premium: -1.9205361136029637 option type: c direction: l
# Option expires 2004-04-15 00:00:00 return: 1.5438308715820312
# State: 0.0
# option invested on 2004-04-29 00:00:00 premium: -1.5526010757565132 option type: c direction: l
# Option expires 2004-06-01 00:00:00 return: 0.6323089599609375
# State: 0.0
# option invested on 2004-06-02 00:00:00 premium: -1.4881260407089627 option type: p direction: l
# Option expires 2004-07-06 00:00:00 return: 0.5975723266601562
# State: 0.0
# option invested on 2004-07-06 00:00:00 premium: -1.5006708007763265 option type: c direction: l
# Option expires 2004-08-06 00:00:00 return: 0
# State: 0.0
# option invested on 2004-08-06 00:00:00 premium: -1.702546891943122 option type: c direction: l
# Option expires 2004-09-07 00:00:00 return: 4.334541320800781
# State: 0.0
# option invested on 2004-09-07 00:00:00 premium: -1.3016693424009347 option type: p direction: l
# Option expires 2004-10-08 00:00:00 return: 0
# State: 0.0
# option invested on 2004-10-14 00:00:00 premium: -1.5064055705485373 option type: c direction: l
# Option expires 2004-11-15 00:00:00 return: 6.1137237548828125
# State: 0.0
# option invested on 2004-11-15 00:00:00 premium: -1.3106468486517642 option type: p direction: l
# Option expires 2004-12-16 00:00:00 return: 0
# State: 0.0
# option invested on 2004-12-16 00:00:00 premium: -1.2012609438255026 option type: p direction: l
# Option expires 2005-01-18 00:00:00 return: 0.5634307861328125
# State: 0.0
# option invested on 2005-01-21 00:00:00 premium: -1.402590801392357 option type: c direction: l
# Option expires 2005-02-22 00:00:00 return: 1.328216552734375
# State: 0.0
# option invested on 2005-02-25 00:00:00 premium: -1.1911851373509208 option type: p direction: l
# Option expires 2005-03-28 00:00:00 return: 2.6704483032226562
# State: 0.0
# option invested on 2005-03-29 00:00:00 premium: -1.417646714337323 option type: c direction: l
# Option expires 2005-04-29 00:00:00 return: 0
# State: 0.0
# option invested on 2005-05-18 00:00:00 premium: -1.325381778338624 option type: p direction: l
# Option expires 2005-06-20 00:00:00 return: 0
# State: 0.0
# option invested on 2005-06-20 00:00:00 premium: -1.160844131310796 option type: p direction: l
# Option expires 2005-07-21 00:00:00 return: 0
# State: 0.0
# option invested on 2005-07-28 00:00:00 premium: -1.0729269023615515 option type: p direction: l
# Option expires 2005-08-29 00:00:00 return: 2.118560791015625
# State: 0.0
# option invested on 2005-09-07 00:00:00 premium: -1.2950197810607236 option type: p direction: l
# Option expires 2005-10-10 00:00:00 return: 3.534759521484375
# State: 0.0
# option invested on 2005-10-10 00:00:00 premium: -1.5599286371985883 option type: c direction: l
# Option expires 2005-11-10 00:00:00 return: 3.5016403198242188
# State: 0.0
# option invested on 2005-11-10 00:00:00 premium: -1.2295176705843076 option type: p direction: l
# Option expires 2005-12-12 00:00:00 return: 0
# State: 0.0
# option invested on 2005-12-14 00:00:00 premium: -1.1012447711023583 option type: p direction: l
# Option expires 2006-01-17 00:00:00 return: 0
# State: 0.0
# option invested on 2006-02-03 00:00:00 premium: -1.466065833836204 option type: c direction: l
# Option expires 2006-03-06 00:00:00 return: 1.4110565185546875
# State: 0.0
# option invested on 2006-03-14 00:00:00 premium: -1.156061820332475 option type: p direction: l
# Option expires 2006-04-17 00:00:00 return: 0.7488555908203125
# State: 0.0
# option invested on 2006-04-17 00:00:00 premium: -1.4095330250149303 option type: c direction: l
# Option expires 2006-05-18 00:00:00 return: 0
# State: 0.0
# option invested on 2006-05-18 00:00:00 premium: -1.8288173037407276 option type: c direction: l
# Option expires 2006-06-19 00:00:00 return: 0
# State: 0.0
# option invested on 2006-06-29 00:00:00 premium: -1.410135069704559 option type: p direction: l
# Option expires 2006-07-31 00:00:00 return: 0
# State: 0.0
# option invested on 2006-08-16 00:00:00 premium: -1.3450885370102483 option type: p direction: l
# Option expires 2006-09-18 00:00:00 return: 0
# State: 0.0
# option invested on 2006-09-18 00:00:00 premium: -1.327508329028646 option type: p direction: l
# Option expires 2006-10-19 00:00:00 return: 0
# State: 0.0
# option invested on 2006-10-23 00:00:00 premium: -1.2762800844900895 option type: p direction: l
# Option expires 2006-11-24 00:00:00 return: 0
# State: 0.0
# option invested on 2006-12-04 00:00:00 premium: -1.3297882254649096 option type: p direction: l
# Option expires 2007-01-04 00:00:00 return: 0
# State: 0.0
# option invested on 2007-01-12 00:00:00 premium: -1.223212489362929 option type: p direction: l
# Option expires 2007-02-12 00:00:00 return: 0
# State: 0.0
# option invested on 2007-02-14 00:00:00 premium: -1.315466745612369 option type: p direction: l
# Option expires 2007-03-19 00:00:00 return: 3.6714630126953125
# State: 0.0
# option invested on 2007-03-23 00:00:00 premium: -1.5744345872983843 option type: p direction: l
# Option expires 2007-04-23 00:00:00 return: 0
# State: 0.0
# option invested on 2007-04-23 00:00:00 premium: -1.6647470030561493 option type: p direction: l
# Option expires 2007-05-24 00:00:00 return: 0
# State: 0.0
# option invested on 2007-05-30 00:00:00 premium: -1.6693934916542617 option type: p direction: l
# Option expires 2007-07-02 00:00:00 return: 0.7865676879882812
# State: 0.0
# option invested on 2007-07-12 00:00:00 premium: -2.0476788877182983 option type: p direction: l
# Option expires 2007-08-13 00:00:00 return: 6.986106872558594
# State: 0.0
# option invested on 2007-08-15 00:00:00 premium: -3.755292914560755 option type: c direction: l
# Option expires 2007-09-17 00:00:00 return: 5.384468078613281
# State: 0.0
# option invested on 2007-09-18 00:00:00 premium: -2.6999599910452687 option type: p direction: l
# Option expires 2007-10-19 00:00:00 return: 1.586334228515625
# State: 0.0
# option invested on 2007-10-19 00:00:00 premium: -3.0036794561961386 option type: c direction: l
# Option expires 2007-11-19 00:00:00 return: 0
# State: 0.0
# option invested on 2007-11-19 00:00:00 premium: -3.3213607656922193 option type: c direction: l
# Option expires 2007-12-20 00:00:00 return: 2.3295516967773438
# State: 0.0
# option invested on 2008-01-04 00:00:00 premium: -2.9716574048861233 option type: c direction: l
# Option expires 2008-02-04 00:00:00 return: 0
# State: 0.0
# option invested on 2008-02-26 00:00:00 premium: -2.7087281737464863 option type: p direction: l
# Option expires 2008-03-28 00:00:00 return: 4.775398254394531
# State: 0.0
# option invested on 2008-04-01 00:00:00 premium: -2.739328312536472 option type: p direction: l
# Option expires 2008-05-02 00:00:00 return: 0
# State: 0.0
# option invested on 2008-05-02 00:00:00 premium: -2.2324569995832064 option type: p direction: l
# Option expires 2008-06-02 00:00:00 return: 2.0205612182617188
# State: 0.0
# option invested on 2008-06-06 00:00:00 premium: -2.8837135853901827 option type: c direction: l
# Option expires 2008-07-07 00:00:00 return: 0
# State: 0.0
# option invested on 2008-07-07 00:00:00 premium: -2.857807079490726 option type: c direction: l
# State: 1.0
# option invested on 2008-07-30 00:00:00 premium: 2.4209766252820373 option type: c direction: s
# Option expires 2008-09-02 00:00:00 return: 0
# State: 0.0
# option invested on 2008-09-04 00:00:00 premium: -2.6896257583305925 option type: c direction: l
# Option expires 2008-10-06 00:00:00 return: 0
# State: 0.0
# option invested on 2008-10-08 00:00:00 premium: -4.9794945501088534 option type: c direction: l
# Option expires 2008-11-10 00:00:00 return: 0
# State: 0.0
# option invested on 2008-11-19 00:00:00 premium: -5.456076955038455 option type: c direction: l
# Option expires 2008-12-22 00:00:00 return: 4.90399169921875
# State: 1.0
# option invested on 2009-01-02 00:00:00 premium: 3.2667046052105064 option type: c direction: s
# Option expires 2009-02-02 00:00:00 return: 0
# State: 0.0
# option invested on 2009-02-18 00:00:00 premium: -3.603556886688036 option type: c direction: l
# State: 1.0
# option invested on 2009-03-18 00:00:00 premium: 2.870824712101495 option type: c direction: s
# State: 1.0
# option invested on 2009-04-09 00:00:00 premium: 2.870824712101495 option type: c direction: s
# Option expires 2009-04-20 00:00:00 return: -3.2322311401367188
# State: 0.0
# option invested on 2009-04-29 00:00:00 premium: -2.868795544192274 option type: p direction: l
# Option expires 2009-06-01 00:00:00 return: 0
# State: 1.0
# option invested on 2009-06-01 00:00:00 premium: 2.6193654546272356 option type: c direction: s
# Option expires 2009-07-02 00:00:00 return: 0
# State: 0.0
# option invested on 2009-07-07 00:00:00 premium: -2.4707716436197273 option type: c direction: l
# Option expires 2009-08-07 00:00:00 return: 10.499313354492188
# State: 0.0
# option invested on 2009-08-21 00:00:00 premium: -2.3124679641643127 option type: p direction: l
# Option expires 2009-09-21 00:00:00 return: 0
# State: 0.0
# option invested on 2009-10-14 00:00:00 premium: -2.253070797049787 option type: p direction: l
# Option expires 2009-11-16 00:00:00 return: 0
# State: 0.0
# option invested on 2009-11-16 00:00:00 premium: -2.3341608899688424 option type: p direction: l
# Option expires 2009-12-17 00:00:00 return: 0.8269195556640625
# State: 0.0
# option invested on 2009-12-21 00:00:00 premium: -2.066082970069104 option type: p direction: l
# Option expires 2010-01-21 00:00:00 return: 0
# State: 0.0
# option invested on 2010-01-25 00:00:00 premium: -2.5660320183423835 option type: c direction: l
# Option expires 2010-02-25 00:00:00 return: 0.7264556884765625
# State: 0.0
# option invested on 2010-03-05 00:00:00 premium: -1.7999005705262903 option type: p direction: l
# Option expires 2010-04-05 00:00:00 return: 0
# State: 0.0
# option invested on 2010-04-05 00:00:00 premium: -1.8661021106045013 option type: p direction: l
# Option expires 2010-05-06 00:00:00 return: 4.7170562744140625
# State: 0.0
# option invested on 2010-05-07 00:00:00 premium: -4.196144175817146 option type: c direction: l
# Option expires 2010-06-07 00:00:00 return: 0
# State: 0.0
# option invested on 2010-06-15 00:00:00 premium: -2.6843966622928974 option type: p direction: l
# Option expires 2010-07-16 00:00:00 return: 3.9166717529296875
# State: 0.0
# option invested on 2010-07-26 00:00:00 premium: -2.3190294148914603 option type: p direction: l
# Option expires 2010-08-26 00:00:00 return: 5.154777526855469
# State: 0.0
# option invested on 2010-08-26 00:00:00 premium: -2.6717891323055554 option type: c direction: l
# Option expires 2010-09-27 00:00:00 return: 7.859809875488281
# State: 0.0
# option invested on 2010-10-05 00:00:00 premium: -2.3208017291950114 option type: p direction: l
# Option expires 2010-11-05 00:00:00 return: 0
# State: 0.0
# option invested on 2010-11-05 00:00:00 premium: -2.0912687861006702 option type: p direction: l
# Option expires 2010-12-06 00:00:00 return: 0
# State: 0.0
# option invested on 2010-12-08 00:00:00 premium: -2.006475658095731 option type: p direction: l
# Option expires 2011-01-10 00:00:00 return: 0
# State: 0.0
# option invested on 2011-01-12 00:00:00 premium: -1.924105740191706 option type: p direction: l
# Option expires 2011-02-14 00:00:00 return: 0
# State: 0.0
# option invested on 2011-02-14 00:00:00 premium: -2.0583339184545366 option type: p direction: l
# Option expires 2011-03-17 00:00:00 return: 4.592376708984375
# State: 0.0
# option invested on 2011-03-17 00:00:00 premium: -3.1616223582826564 option type: c direction: l
# Option expires 2011-04-18 00:00:00 return: 2.6971359252929688
# State: 0.0
# option invested on 2011-04-26 00:00:00 premium: -1.9805075433737471 option type: p direction: l
# Option expires 2011-05-27 00:00:00 return: 1.05804443359375
# State: 0.0
# option invested on 2011-06-01 00:00:00 premium: -2.3192513324368775 option type: c direction: l
# Option expires 2011-07-05 00:00:00 return: 2.1519622802734375
# State: 0.0
# option invested on 2011-07-05 00:00:00 premium: -1.9983952319017604 option type: p direction: l
# Option expires 2011-08-05 00:00:00 return: 11.405288696289062
# State: 0.0
# option invested on 2011-08-05 00:00:00 premium: -3.6323540169051896 option type: c direction: l
# Option expires 2011-09-06 00:00:00 return: 0
# State: 0.0
# option invested on 2011-09-23 00:00:00 premium: -4.519857357488924 option type: c direction: l
# Option expires 2011-10-24 00:00:00 return: 9.977981567382812
# State: 0.0
# option invested on 2011-10-24 00:00:00 premium: -3.448741550750661 option type: p direction: l
# State: 1.0
# option invested on 2011-10-27 00:00:00 premium: 3.116610774239625 option type: c direction: s
# Option expires 2011-11-28 00:00:00 return: 0
# State: 0.0
# option invested on 2012-01-03 00:00:00 premium: -2.76386848455531 option type: p direction: l
# Option expires 2012-02-03 00:00:00 return: 0
# State: 0.0
# option invested on 2012-02-03 00:00:00 premium: -2.238149285779805 option type: p direction: l
# Option expires 2012-03-05 00:00:00 return: 0
# State: 0.0
# option invested on 2012-03-13 00:00:00 premium: -1.948068437511786 option type: p direction: l
# Option expires 2012-04-13 00:00:00 return: 1.9486007690429688
# State: 0.0
# option invested on 2012-04-13 00:00:00 premium: -2.629145255411963 option type: c direction: l
# Option expires 2012-05-14 00:00:00 return: 0
# State: 0.0
# option invested on 2012-05-14 00:00:00 premium: -2.8246062972618446 option type: c direction: l
# Option expires 2012-06-14 00:00:00 return: 0
# State: 0.0
# option invested on 2012-06-15 00:00:00 premium: -2.741856734128497 option type: p direction: l
# Option expires 2012-07-16 00:00:00 return: 0
# State: 0.0
# option invested on 2012-07-27 00:00:00 premium: -2.2003399067301572 option type: p direction: l
# Option expires 2012-08-27 00:00:00 return: 0
# State: 0.0
# option invested on 2012-09-06 00:00:00 premium: -2.1652219078467994 option type: p direction: l
# Option expires 2012-10-08 00:00:00 return: 0
# State: 0.0
# option invested on 2012-10-10 00:00:00 premium: -2.277968666729592 option type: c direction: l
# Option expires 2012-11-12 00:00:00 return: 0
# State: 0.0
# option invested on 2012-11-12 00:00:00 premium: -2.2892274942895483 option type: c direction: l
# Option expires 2012-12-13 00:00:00 return: 3.7184219360351562
# State: 0.0
# option invested on 2012-12-17 00:00:00 premium: -2.243320841690256 option type: p direction: l
# State: 1.0
# option invested on 2013-01-02 00:00:00 premium: 2.110050706944989 option type: c direction: s
# Option expires 2013-02-04 00:00:00 return: -2.98895263671875
# State: 0.0
# option invested on 2013-02-08 00:00:00 premium: -1.989711357975544 option type: p direction: l
# Option expires 2013-03-11 00:00:00 return: 0
# State: 0.0
# option invested on 2013-03-11 00:00:00 premium: -1.726878407465648 option type: p direction: l
# Option expires 2013-04-11 00:00:00 return: 0
# State: 0.0
# option invested on 2013-04-11 00:00:00 premium: -1.906955624722812 option type: p direction: l
# Option expires 2013-05-13 00:00:00 return: 0
# State: 0.0
# option invested on 2013-05-14 00:00:00 premium: -2.032053687096422 option type: p direction: l
# Option expires 2013-06-14 00:00:00 return: 1.7686309814453125
# State: 0.0
# option invested on 2013-06-21 00:00:00 premium: -3.0306826550545622 option type: c direction: l
# Option expires 2013-07-22 00:00:00 return: 9.045867919921875
# State: 0.0
# option invested on 2013-08-02 00:00:00 premium: -1.9809572765747987 option type: p direction: l
# Option expires 2013-09-03 00:00:00 return: 5.6894378662109375
# State: 0.0
# option invested on 2013-09-10 00:00:00 premium: -2.419695537362216 option type: p direction: l
# Option expires 2013-10-11 00:00:00 return: 0
# State: 0.0
# option invested on 2013-10-16 00:00:00 premium: -2.4670089520601834 option type: p direction: l
# Option expires 2013-11-18 00:00:00 return: 0
# State: 0.0
# option invested on 2013-11-18 00:00:00 premium: -2.325998694658608 option type: p direction: l
# Option expires 2013-12-19 00:00:00 return: 0
# State: 0.0
# option invested on 2013-12-20 00:00:00 premium: -2.4515489250615303 option type: p direction: l
# Option expires 2014-01-21 00:00:00 return: 0
# State: 0.0
# option invested on 2014-01-27 00:00:00 premium: -3.1072310390133424 option type: c direction: l
# Option expires 2014-02-27 00:00:00 return: 6.843505859375
# State: 0.0
# option invested on 2014-03-06 00:00:00 premium: -2.6193180268708574 option type: p direction: l
# Option expires 2014-04-07 00:00:00 return: 2.6518707275390625
# State: 0.0
# option invested on 2014-04-10 00:00:00 premium: -2.98277753806957 option type: c direction: l
# Option expires 2014-05-12 00:00:00 return: 5.8351593017578125
# State: 0.0
# option invested on 2014-05-12 00:00:00 premium: -2.279062821794014 option type: p direction: l
# Option expires 2014-06-12 00:00:00 return: 0
# State: 0.0
# option invested on 2014-06-20 00:00:00 premium: -2.128716967592652 option type: p direction: l
# Option expires 2014-07-21 00:00:00 return: 0
# State: 0.0
# option invested on 2014-07-23 00:00:00 premium: -2.255604147738552 option type: p direction: l
# Option expires 2014-08-25 00:00:00 return: 0
# State: 0.0
# option invested on 2014-08-25 00:00:00 premium: -2.3093870447660834 option type: p direction: l
# Option expires 2014-09-25 00:00:00 return: 2.6018829345703125
# State: 0.0
# option invested on 2014-09-25 00:00:00 premium: -3.177555671216325 option type: c direction: l
# Option expires 2014-10-27 00:00:00 return: 0
# State: 0.0
# option invested on 2014-10-31 00:00:00 premium: -2.8095888964298013 option type: p direction: l
# Option expires 2014-12-01 00:00:00 return: 0
# State: 0.0
# option invested on 2014-12-03 00:00:00 premium: -2.5765449352330734 option type: p direction: l
# Option expires 2015-01-05 00:00:00 return: 4.49267578125
# State: 0.0
# option invested on 2015-01-15 00:00:00 premium: -4.541783283245394 option type: c direction: l
# Option expires 2015-02-17 00:00:00 return: 9.907501220703125
# State: 0.0
# option invested on 2015-02-17 00:00:00 premium: -3.484871392066907 option type: p direction: l
# Option expires 2015-03-20 00:00:00 return: 0
# State: 0.0
# option invested on 2015-04-23 00:00:00 premium: -2.6834075421285633 option type: p direction: l
# Option expires 2015-05-26 00:00:00 return: 0.4128265380859375
# State: 0.0
# option invested on 2015-06-05 00:00:00 premium: -3.1190284441757683 option type: c direction: l
# Option expires 2015-07-06 00:00:00 return: 0
# State: 0.0
# option invested on 2015-07-08 00:00:00 premium: -4.1414458748489835 option type: c direction: l
# Option expires 2015-08-10 00:00:00 return: 5.4464263916015625
# State: 0.0
# option invested on 2015-08-20 00:00:00 premium: -4.021878747183237 option type: c direction: l
# Option expires 2015-09-21 00:00:00 return: 0
# State: 0.0
# option invested on 2015-09-28 00:00:00 premium: -5.455604375439847 option type: c direction: l
# Option expires 2015-10-29 00:00:00 return: 18.871505737304688
# State: 0.0
# option invested on 2015-10-29 00:00:00 premium: -3.0924988645576263 option type: p direction: l
# Option expires 2015-11-30 00:00:00 return: 0.126861572265625
# State: 0.0
# option invested on 2015-12-11 00:00:00 premium: -5.088368393540179 option type: c direction: l
# Option expires 2016-01-11 00:00:00 return: 0
# State: 0.0
# option invested on 2016-01-11 00:00:00 premium: -4.853098465816743 option type: c direction: l
# Option expires 2016-02-11 00:00:00 return: 0
# State: 0.0
# option invested on 2016-02-11 00:00:00 premium: -5.525917667806084 option type: c direction: l
# Option expires 2016-03-14 00:00:00 return: 17.907943725585938
# State: 0.0
# option invested on 2016-03-14 00:00:00 premium: -3.499315054319979 option type: p direction: l
# Option expires 2016-04-14 00:00:00 return: 0
# State: 0.0
# option invested on 2016-04-14 00:00:00 premium: -2.971913288764128 option type: p direction: l
# Option expires 2016-05-16 00:00:00 return: 1.127288818359375
# State: 0.0
# option invested on 2016-05-25 00:00:00 premium: -2.9795583518986746 option type: p direction: l
# Option expires 2016-06-27 00:00:00 return: 7.9204864501953125
# State: 0.0
# option invested on 2016-06-27 00:00:00 premium: -5.08712663391664 option type: c direction: l
# Option expires 2016-07-28 00:00:00 return: 15.818313598632812
# State: 0.0
# option invested on 2016-08-05 00:00:00 premium: -2.5514033043724993 option type: p direction: l
# Option expires 2016-09-06 00:00:00 return: 0
# State: 0.0
# option invested on 2016-09-09 00:00:00 premium: -3.9998400408229315 option type: c direction: l
# Option expires 2016-10-10 00:00:00 return: 3.6592254638671875
# State: 0.0
# option invested on 2016-10-13 00:00:00 premium: -3.766033859640359 option type: c direction: l
# Option expires 2016-11-14 00:00:00 return: 3.3148345947265625
# State: 0.0
# option invested on 2016-11-15 00:00:00 premium: -3.0692686684407846 option type: p direction: l
# Option expires 2016-12-16 00:00:00 return: 0
# State: 0.0
# option invested on 2017-01-06 00:00:00 premium: -2.669395123037347 option type: p direction: l
# Option expires 2017-02-06 00:00:00 return: 0
# State: 0.0
# option invested on 2017-02-09 00:00:00 premium: -2.731214611867358 option type: p direction: l
# Option expires 2017-03-13 00:00:00 return: 0
# State: 0.0
# option invested on 2017-03-15 00:00:00 premium: -2.8854109665971635 option type: p direction: l
# Option expires 2017-04-17 00:00:00 return: 3.1290435791015625
# State: 0.0
# option invested on 2017-04-24 00:00:00 premium: -2.722992315711437 option type: p direction: l
# Option expires 2017-05-25 00:00:00 return: 0
# State: 0.0
# option invested on 2017-05-25 00:00:00 premium: -2.5122586014937127 option type: p direction: l
# Option expires 2017-06-26 00:00:00 return: 0
# State: 0.0
# option invested on 2017-06-27 00:00:00 premium: -2.936219101924692 option type: c direction: l
# Option expires 2017-07-28 00:00:00 return: 5.245208740234375
# State: 0.0
# option invested on 2017-08-10 00:00:00 premium: -4.206635295879991 option type: c direction: l
# Option expires 2017-09-11 00:00:00 return: 5.12298583984375
# State: 0.0
# option invested on 2017-09-11 00:00:00 premium: -2.8455148107214256 option type: p direction: l
# Option expires 2017-10-12 00:00:00 return: 0
# State: 0.0
# option invested on 2017-10-20 00:00:00 premium: -2.692624363654147 option type: p direction: l
# Option expires 2017-11-20 00:00:00 return: 0
# State: 0.0
# option invested on 2017-11-21 00:00:00 premium: -2.7006036579789736 option type: p direction: l
# Option expires 2017-12-22 00:00:00 return: 0
# State: 0.0
# option invested on 2018-01-03 00:00:00 premium: -2.608670277550104 option type: p direction: l
# Option expires 2018-02-05 00:00:00 return: 6.2097015380859375
# State: 0.0
# option invested on 2018-02-06 00:00:00 premium: -9.163973781277662 option type: c direction: l
# Option expires 2018-03-09 00:00:00 return: 9.248062133789062
# State: 0.0
# option invested on 2018-03-09 00:00:00 premium: -4.334976537962433 option type: p direction: l
# Option expires 2018-04-09 00:00:00 return: 15.974960327148438
# State: 0.0
# option invested on 2018-04-17 00:00:00 premium: -4.46887844382735 option type: p direction: l
# Option expires 2018-05-18 00:00:00 return: 0
# State: 0.0
# option invested on 2018-06-04 00:00:00 premium: -3.789610119397153 option type: p direction: l
# Option expires 2018-07-05 00:00:00 return: 0.537353515625
# State: 0.0
# option invested on 2018-07-10 00:00:00 premium: -3.7678211278198432 option type: p direction: l
# Option expires 2018-08-10 00:00:00 return: 0
# State: 0.0
# option invested on 2018-08-21 00:00:00 premium: -3.9366056191406074 option type: p direction: l
# Option expires 2018-09-21 00:00:00 return: 0
# State: 0.0
# option invested on 2018-09-21 00:00:00 premium: -3.7188591248253147 option type: p direction: l
# Option expires 2018-10-22 00:00:00 return: 16.333282470703125
# State: 0.0
# option invested on 2018-10-26 00:00:00 premium: -7.030694289874674 option type: c direction: l
# Option expires 2018-11-26 00:00:00 return: 2.087371826171875
# State: 0.0
# option invested on 2018-12-07 00:00:00 premium: -6.717291432691255 option type: c direction: l
# Option expires 2019-01-07 00:00:00 return: 0
# State: 0.0
# option invested on 2019-01-18 00:00:00 premium: -5.14272392855753 option type: p direction: l
# Option expires 2019-02-19 00:00:00 return: 0
# State: 0.0
# option invested on 2019-02-19 00:00:00 premium: -4.696929241037196 option type: p direction: l
# Option expires 2019-03-22 00:00:00 return: 0
# State: 0.0
# option invested on 2019-04-01 00:00:00 premium: -4.227760572152931 option type: p direction: l
# Option expires 2019-05-02 00:00:00 return: 0
# State: 0.0
# option invested on 2019-05-03 00:00:00 premium: -4.105563983784066 option type: p direction: l
# Option expires 2019-06-03 00:00:00 return: 18.9111328125
# State: 0.0
# option invested on 2019-06-03 00:00:00 premium: -5.849282845448897 option type: c direction: l
# Option expires 2019-07-05 00:00:00 return: 24.6268310546875
# State: 0.0
# option invested on 2019-07-05 00:00:00 premium: -4.322934070126507 option type: p direction: l
# Option expires 2019-08-05 00:00:00 return: 14.296234130859375
# State: 0.0
# option invested on 2019-08-06 00:00:00 premium: -6.473103651083818 option type: c direction: l
# Option expires 2019-09-06 00:00:00 return: 10.00933837890625
# State: 0.0
# option invested on 2019-09-06 00:00:00 premium: -4.966000427455157 option type: p direction: l
# Option expires 2019-10-07 00:00:00 return: 3.53167724609375
# State: 0.0
# option invested on 2019-10-08 00:00:00 premium: -6.554724186528318 option type: c direction: l
# Option expires 2019-11-08 00:00:00 return: 20.0228271484375
# State: 0.0
# option invested on 2019-11-08 00:00:00 premium: -4.148996771640583 option type: p direction: l
# Option expires 2019-12-09 00:00:00 return: 0
# State: 0.0
# option invested on 2019-12-12 00:00:00 premium: -4.846960596099223 option type: p direction: l
# pf end value: 532.9024887626688

# %%
pf_df.plot()
